# %% [markdown]
# <a href="https://colab.research.google.com/github/Redcoder815/Deep_learning_phitron/blob/main/09Backpropagation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

data = torch.tensor(
    [
        [2,3,3],
        [5,6,4],
        [7,8,5]
    ]
)
data
# Out:
# tensor([[2, 3, 3],
#         [5, 6, 4],
#         [7, 8, 5]])

# %%
X = data[:,0:2].float()
y = data[:,2].float()

# %%
X
# Out:
# tensor([[2., 3.],
#         [5., 6.],
#         [7., 8.]])

# %%
y
# Out:
# tensor([3., 4., 5.])

# %%
def initialize_parameters(layer_dims):
  torch.manual_seed(3)
  parameters = {}
  L = len(layer_dims)

  for l in range(1, L):
    parameters["W" + str(l)] = torch.ones((layer_dims[l-1], layer_dims[l])) * 0.1
    parameters["b" + str(l)] = torch.zeros((layer_dims[l], 1))

  return parameters

# %%
initialize_parameters( [2,2,1] )
# Out:
# {'W1': tensor([[0.1000, 0.1000],
#          [0.1000, 0.1000]]),
#  'b1': tensor([[0.],
#          [0.]]),
#  'W2': tensor([[0.1000],
#          [0.1000]]),
#  'b2': tensor([[0.]])}

# %%
def linear_forward(A_prev, W, b):
  Z = torch.matmul(W.T, A_prev) + b
  return Z

# %%
def L_layer_forward(X,parameters):
  A = X
  L = len(parameters)//2
  print('Length of parameters ', L)
  for l in range(1,L+1):
    A_prev = A

    wl = parameters['W' + str(l)]
    bl = parameters['b' + str(l)]
    A = linear_forward( A_prev, wl, bl )

  return A, A_prev

# %%
params = initialize_parameters([2,2,1])
X_sample = X[0].reshape(2,1)
y_hat, A1 = L_layer_forward(X_sample,params)
# Out:
# Length of parameters  2

# %%
def update_parameters(parameters, y, y_hat, A1, X, lr=0.001):

    err_signal = 2 * (y - y_hat)

     #  Save OLD W2 values before updating
    W2_00_old = parameters['W2'][0, 0].item()
    W2_10_old = parameters['W2'][1, 0].item()

    # Update Layer 2




    parameters['W2'][0, 0] += lr * err_signal * A1[0, 0]
    parameters['W2'][1, 0] += lr * err_signal * A1[1, 0]
    parameters['b2'][0, 0] += lr * err_signal #


    parameters['W1'][0, 0] += lr * err_signal * parameters['W2'][0, 0] * X[0, 0]
    parameters['W1'][0, 1] += lr * err_signal * parameters['W2'][0, 0] * X[1, 0]
    parameters['b1'][0, 0] += lr * err_signal * parameters['W2'][0, 0]

    parameters['W1'][1, 0] += lr * err_signal * parameters['W2'][1, 0] * X[0, 0]
    parameters['W1'][1, 1] += lr * err_signal * parameters['W2'][1, 0] * X[1, 0]
    parameters['b1'][1, 0] += lr * err_signal * parameters['W2'][1, 0]

    return parameters

# %%
params = initialize_parameters([2, 2, 1])
epochs = 15

for i in range(epochs):
    epoch_loss = 0
    for j in range(X.shape[0]):
        # Prepare sample
        X_sample = X[j].reshape(2, 1)
        y_sample = y[j]

        print(f'X_sample {X_sample}')
        print(f'y_sample {y_sample}')

        # Forward
        y_hat, A1 = L_layer_forward(X_sample, params)
        y_hat_scalar = y_hat[0, 0]

        # Update
        print(f'Old parames {params}')
        params = update_parameters(params, y_sample, y_hat_scalar, A1, X_sample)
        print(f'iteration i and j {i} and {j} er parames {params}')

        # Loss calculation
        loss = (y_sample - y_hat_scalar) ** 2
        epoch_loss += loss.item()

    print(f"Epoch - {i+1} Loss - {epoch_loss / X.shape[0]}")
# Out:
# X_sample tensor([[2.],
#         [3.]])
# y_sample 3.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.1000, 0.1000],
#         [0.1000, 0.1000]]), 'b1': tensor([[0.],
#         [0.]]), 'W2': tensor([[0.1000],
#         [0.1000]]), 'b2': tensor([[0.]])}
# iteration i and j 0 and 0 er parames {'W1': tensor([[0.1012, 0.1018],
#         [0.1012, 0.1018]]), 'b1': tensor([[0.0006],
#         [0.0006]]), 'W2': tensor([[0.1029],
#         [0.1029]]), 'b2': tensor([[0.0058]])}
# X_sample tensor([[5.],
#         [6.]])
# y_sample 4.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.1012, 0.1018],
#         [0.1012, 0.1018]]), 'b1': tensor([[0.0006],
#         [0.0006]]), 'W2': tensor([[0.1029],
#         [0.1029]]), 'b2': tensor([[0.0058]])}
# iteration i and j 0 and 1 er parames {'W1': tensor([[0.1054, 0.1068],
#         [0.1054, 0.1068]]), 'b1': tensor([[0.0014],
#         [0.0014]]), 'W2': tensor([[0.1113],
#         [0.1113]]), 'b2': tensor([[0.0133]])}
# X_sample tensor([[7.],
#         [8.]])
# y_sample 5.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.1054, 0.1068],
#         [0.1054, 0.1068]]), 'b1': tensor([[0.0014],
#         [0.0014]]), 'W2': tensor([[0.1113],
#         [0.1113]]), 'b2': tensor([[0.0133]])}
# iteration i and j 0 and 2 er parames {'W1': tensor([[0.1135, 0.1162],
#         [0.1136, 0.1162]]), 'b1': tensor([[0.0026],
#         [0.0026]]), 'W2': tensor([[0.1259],
#         [0.1262]]), 'b2': tensor([[0.0226]])}
# Epoch - 1 Loss - 14.67866039276123
# X_sample tensor([[2.],
#         [3.]])
# y_sample 3.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.1135, 0.1162],
#         [0.1136, 0.1162]]), 'b1': tensor([[0.0026],
#         [0.0026]]), 'W2': tensor([[0.1259],
#         [0.1262]]), 'b2': tensor([[0.0226]])}
# iteration i and j 1 and 0 er parames {'W1': tensor([[0.1150, 0.1183],
#         [0.1150, 0.1184]]), 'b1': tensor([[0.0033],
#         [0.0033]]), 'W2': tensor([[0.1292],
#         [0.1295]]), 'b2': tensor([[0.0283]])}
# X_sample tensor([[5.],
#         [6.]])
# y_sample 4.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.1150, 0.1183],
#         [0.1150, 0.1184]]), 'b1': tensor([[0.0033],
#         [0.0033]]), 'W2': tensor([[0.1292],
#         [0.1295]]), 'b2': tensor([[0.0283]])}
# iteration i and j 1 and 1 er parames {'W1': tensor([[0.1200, 0.1244],
#         [0.1201, 0.1244]]), 'b1': tensor([[0.0043],
#         [0.0043]]), 'W2': tensor([[0.1384],
#         [0.1390]]), 'b2': tensor([[0.0355]])}
# X_sample tensor([[7.],
#         [8.]])
# y_sample 5.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.1200, 0.1244],
#         [0.1201, 0.1244]]), 'b1': tensor([[0.0043],
#         [0.0043]]), 'W2': tensor([[0.1384],
#         [0.1390]]), 'b2': tensor([[0.0355]])}
# iteration i and j 1 and 2 er parames {'W1': tensor([[0.1297, 0.1354],
#         [0.1298, 0.1355]]), 'b1': tensor([[0.0057],
#         [0.0057]]), 'W2': tensor([[0.1545],
#         [0.1557]]), 'b2': tensor([[0.0444]])}
# Epoch - 2 Loss - 13.701451301574707
# X_sample tensor([[2.],
#         [3.]])
# y_sample 3.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.1297, 0.1354],
#         [0.1298, 0.1355]]), 'b1': tensor([[0.0057],
#         [0.0057]]), 'W2': tensor([[0.1545],
#         [0.1557]]), 'b2': tensor([[0.0444]])}
# iteration i and j 2 and 0 er parames {'W1': tensor([[0.1314, 0.1380],
#         [0.1316, 0.1382]]), 'b1': tensor([[0.0066],
#         [0.0066]]), 'W2': tensor([[0.1581],
#         [0.1594]]), 'b2': tensor([[0.0499]])}
# X_sample tensor([[5.],
#         [6.]])
# y_sample 4.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.1314, 0.1380],
#         [0.1316, 0.1382]]), 'b1': tensor([[0.0066],
#         [0.0066]]), 'W2': tensor([[0.1581],
#         [0.1594]]), 'b2': tensor([[0.0499]])}
# iteration i and j 2 and 1 er parames {'W1': tensor([[0.1373, 0.1450],
#         [0.1375, 0.1453]]), 'b1': tensor([[0.0078],
#         [0.0078]]), 'W2': tensor([[0.1682],
#         [0.1700]]), 'b2': tensor([[0.0569]])}
# X_sample tensor([[7.],
#         [8.]])
# y_sample 5.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.1373, 0.1450],
#         [0.1375, 0.1453]]), 'b1': tensor([[0.0078],
#         [0.0078]]), 'W2': tensor([[0.1682],
#         [0.1700]]), 'b2': tensor([[0.0569]])}
# iteration i and j 2 and 2 er parames {'W1': tensor([[0.1482, 0.1576],
#         [0.1486, 0.1580]]), 'b1': tensor([[0.0093],
#         [0.0094]]), 'W2': tensor([[0.1857],
#         [0.1885]]), 'b2': tensor([[0.0653]])}
# Epoch - 3 Loss - 12.494118690490723
# X_sample tensor([[2.],
#         [3.]])
# y_sample 3.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.1482, 0.1576],
#         [0.1486, 0.1580]]), 'b1': tensor([[0.0093],
#         [0.0094]]), 'W2': tensor([[0.1857],
#         [0.1885]]), 'b2': tensor([[0.0653]])}
# iteration i and j 3 and 0 er parames {'W1': tensor([[0.1503, 0.1606],
#         [0.1506, 0.1611]]), 'b1': tensor([[0.0103],
#         [0.0104]]), 'W2': tensor([[0.1896],
#         [0.1927]]), 'b2': tensor([[0.0706]])}
# X_sample tensor([[5.],
#         [6.]])
# y_sample 4.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.1503, 0.1606],
#         [0.1506, 0.1611]]), 'b1': tensor([[0.0103],
#         [0.0104]]), 'W2': tensor([[0.1896],
#         [0.1927]]), 'b2': tensor([[0.0706]])}
# iteration i and j 3 and 1 er parames {'W1': tensor([[0.1568, 0.1685],
#         [0.1573, 0.1691]]), 'b1': tensor([[0.0116],
#         [0.0117]]), 'W2': tensor([[0.2005],
#         [0.2043]]), 'b2': tensor([[0.0772]])}
# X_sample tensor([[7.],
#         [8.]])
# y_sample 5.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.1568, 0.1685],
#         [0.1573, 0.1691]]), 'b1': tensor([[0.0116],
#         [0.0117]]), 'W2': tensor([[0.2005],
#         [0.2043]]), 'b2': tensor([[0.0772]])}
# iteration i and j 3 and 2 er parames {'W1': tensor([[0.1689, 0.1822],
#         [0.1697, 0.1832]]), 'b1': tensor([[0.0134],
#         [0.0135]]), 'W2': tensor([[0.2191],
#         [0.2243]]), 'b2': tensor([[0.0850]])}
# Epoch - 4 Loss - 11.040447076161703
# X_sample tensor([[2.],
#         [3.]])
# y_sample 3.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.1689, 0.1822],
#         [0.1697, 0.1832]]), 'b1': tensor([[0.0134],
#         [0.0135]]), 'W2': tensor([[0.2191],
#         [0.2243]]), 'b2': tensor([[0.0850]])}
# iteration i and j 4 and 0 er parames {'W1': tensor([[0.1711, 0.1856],
#         [0.1720, 0.1866]]), 'b1': tensor([[0.0145],
#         [0.0147]]), 'W2': tensor([[0.2235],
#         [0.2290]]), 'b2': tensor([[0.0901]])}
# X_sample tensor([[5.],
#         [6.]])
# y_sample 4.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.1711, 0.1856],
#         [0.1720, 0.1866]]), 'b1': tensor([[0.0145],
#         [0.0147]]), 'W2': tensor([[0.2235],
#         [0.2290]]), 'b2': tensor([[0.0901]])}
# iteration i and j 4 and 1 er parames {'W1': tensor([[0.1782, 0.1941],
#         [0.1792, 0.1954]]), 'b1': tensor([[0.0159],
#         [0.0161]]), 'W2': tensor([[0.2349],
#         [0.2414]]), 'b2': tensor([[0.0961]])}
# X_sample tensor([[7.],
#         [8.]])
# y_sample 5.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.1782, 0.1941],
#         [0.1792, 0.1954]]), 'b1': tensor([[0.0159],
#         [0.0161]]), 'W2': tensor([[0.2349],
#         [0.2414]]), 'b2': tensor([[0.0961]])}
# iteration i and j 4 and 2 er parames {'W1': tensor([[0.1909, 0.2086],
#         [0.1923, 0.2103]]), 'b1': tensor([[0.0177],
#         [0.0180]]), 'W2': tensor([[0.2541],
#         [0.2624]]), 'b2': tensor([[0.1032]])}
# Epoch - 5 Loss - 9.366330782572428
# X_sample tensor([[2.],
#         [3.]])
# y_sample 3.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.1909, 0.2086],
#         [0.1923, 0.2103]]), 'b1': tensor([[0.0177],
#         [0.0180]]), 'W2': tensor([[0.2541],
#         [0.2624]]), 'b2': tensor([[0.1032]])}
# iteration i and j 5 and 0 er parames {'W1': tensor([[0.1933, 0.2123],
#         [0.1949, 0.2141]]), 'b1': tensor([[0.0189],
#         [0.0192]]), 'W2': tensor([[0.2588],
#         [0.2674]]), 'b2': tensor([[0.1080]])}
# X_sample tensor([[5.],
#         [6.]])
# y_sample 4.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.1933, 0.2123],
#         [0.1949, 0.2141]]), 'b1': tensor([[0.0189],
#         [0.0192]]), 'W2': tensor([[0.2588],
#         [0.2674]]), 'b2': tensor([[0.1080]])}
# iteration i and j 5 and 1 er parames {'W1': tensor([[0.2006, 0.2210],
#         [0.2024, 0.2232]]), 'b1': tensor([[0.0204],
#         [0.0208]]), 'W2': tensor([[0.2704],
#         [0.2802]]), 'b2': tensor([[0.1134]])}
# X_sample tensor([[7.],
#         [8.]])
# y_sample 5.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.2006, 0.2210],
#         [0.2024, 0.2232]]), 'b1': tensor([[0.0204],
#         [0.0208]]), 'W2': tensor([[0.2704],
#         [0.2802]]), 'b2': tensor([[0.1134]])}
# iteration i and j 5 and 2 er parames {'W1': tensor([[0.2133, 0.2355],
#         [0.2156, 0.2382]]), 'b1': tensor([[0.0222],
#         [0.0226]]), 'W2': tensor([[0.2894],
#         [0.3011]]), 'b2': tensor([[0.1196]])}
# Epoch - 6 Loss - 7.557169596354167
# X_sample tensor([[2.],
#         [3.]])
# y_sample 3.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.2133, 0.2355],
#         [0.2156, 0.2382]]), 'b1': tensor([[0.0222],
#         [0.0226]]), 'W2': tensor([[0.2894],
#         [0.3011]]), 'b2': tensor([[0.1196]])}
# iteration i and j 6 and 0 er parames {'W1': tensor([[0.2159, 0.2394],
#         [0.2183, 0.2423]]), 'b1': tensor([[0.0235],
#         [0.0240]]), 'W2': tensor([[0.2942],
#         [0.3065]]), 'b2': tensor([[0.1240]])}
# X_sample tensor([[5.],
#         [6.]])
# y_sample 4.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.2159, 0.2394],
#         [0.2183, 0.2423]]), 'b1': tensor([[0.0235],
#         [0.0240]]), 'W2': tensor([[0.2942],
#         [0.3065]]), 'b2': tensor([[0.1240]])}
# iteration i and j 6 and 1 er parames {'W1': tensor([[0.2230, 0.2480],
#         [0.2258, 0.2513]]), 'b1': tensor([[0.0249],
#         [0.0255]]), 'W2': tensor([[0.3056],
#         [0.3190]]), 'b2': tensor([[0.1287]])}
# X_sample tensor([[7.],
#         [8.]])
# y_sample 5.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.2230, 0.2480],
#         [0.2258, 0.2513]]), 'b1': tensor([[0.0249],
#         [0.0255]]), 'W2': tensor([[0.3056],
#         [0.3190]]), 'b2': tensor([[0.1287]])}
# iteration i and j 6 and 2 er parames {'W1': tensor([[0.2350, 0.2616],
#         [0.2383, 0.2655]]), 'b1': tensor([[0.0266],
#         [0.0273]]), 'W2': tensor([[0.3234],
#         [0.3389]]), 'b2': tensor([[0.1340]])}
# Epoch - 7 Loss - 5.7561141649882
# X_sample tensor([[2.],
#         [3.]])
# y_sample 3.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.2350, 0.2616],
#         [0.2383, 0.2655]]), 'b1': tensor([[0.0266],
#         [0.0273]]), 'W2': tensor([[0.3234],
#         [0.3389]]), 'b2': tensor([[0.1340]])}
# iteration i and j 7 and 0 er parames {'W1': tensor([[0.2376, 0.2656],
#         [0.2410, 0.2697]]), 'b1': tensor([[0.0280],
#         [0.0287]]), 'W2': tensor([[0.3283],
#         [0.3443]]), 'b2': tensor([[0.1380]])}
# X_sample tensor([[5.],
#         [6.]])
# y_sample 4.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.2376, 0.2656],
#         [0.2410, 0.2697]]), 'b1': tensor([[0.0280],
#         [0.0287]]), 'W2': tensor([[0.3283],
#         [0.3443]]), 'b2': tensor([[0.1380]])}
# iteration i and j 7 and 1 er parames {'W1': tensor([[0.2443, 0.2736],
#         [0.2480, 0.2781]]), 'b1': tensor([[0.0293],
#         [0.0301]]), 'W2': tensor([[0.3388],
#         [0.3560]]), 'b2': tensor([[0.1419]])}
# X_sample tensor([[7.],
#         [8.]])
# y_sample 5.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.2443, 0.2736],
#         [0.2480, 0.2781]]), 'b1': tensor([[0.0293],
#         [0.0301]]), 'W2': tensor([[0.3388],
#         [0.3560]]), 'b2': tensor([[0.1419]])}
# iteration i and j 7 and 2 er parames {'W1': tensor([[0.2547, 0.2855],
#         [0.2591, 0.2907]]), 'b1': tensor([[0.0308],
#         [0.0316]]), 'W2': tensor([[0.3545],
#         [0.3736]]), 'b2': tensor([[0.1461]])}
# Epoch - 8 Loss - 4.130068461100261
# X_sample tensor([[2.],
#         [3.]])
# y_sample 3.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.2547, 0.2855],
#         [0.2591, 0.2907]]), 'b1': tensor([[0.0308],
#         [0.0316]]), 'W2': tensor([[0.3545],
#         [0.3736]]), 'b2': tensor([[0.1461]])}
# iteration i and j 8 and 0 er parames {'W1': tensor([[0.2574, 0.2895],
#         [0.2619, 0.2949]]), 'b1': tensor([[0.0321],
#         [0.0330]]), 'W2': tensor([[0.3593],
#         [0.3790]]), 'b2': tensor([[0.1498]])}
# X_sample tensor([[5.],
#         [6.]])
# y_sample 4.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.2574, 0.2895],
#         [0.2619, 0.2949]]), 'b1': tensor([[0.0321],
#         [0.0330]]), 'W2': tensor([[0.3593],
#         [0.3790]]), 'b2': tensor([[0.1498]])}
# iteration i and j 8 and 1 er parames {'W1': tensor([[0.2632, 0.2965],
#         [0.2680, 0.3023]]), 'b1': tensor([[0.0333],
#         [0.0343]]), 'W2': tensor([[0.3685],
#         [0.3893]]), 'b2': tensor([[0.1530]])}
# X_sample tensor([[7.],
#         [8.]])
# y_sample 5.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.2632, 0.2965],
#         [0.2680, 0.3023]]), 'b1': tensor([[0.0333],
#         [0.0343]]), 'W2': tensor([[0.3685],
#         [0.3893]]), 'b2': tensor([[0.1530]])}
# iteration i and j 8 and 2 er parames {'W1': tensor([[0.2718, 0.3063],
#         [0.2771, 0.3126]]), 'b1': tensor([[0.0345],
#         [0.0356]]), 'W2': tensor([[0.3814],
#         [0.4038]]), 'b2': tensor([[0.1562]])}
# Epoch - 9 Loss - 2.812238613764445
# X_sample tensor([[2.],
#         [3.]])
# y_sample 3.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.2718, 0.3063],
#         [0.2771, 0.3126]]), 'b1': tensor([[0.0345],
#         [0.0356]]), 'W2': tensor([[0.3814],
#         [0.4038]]), 'b2': tensor([[0.1562]])}
# iteration i and j 9 and 0 er parames {'W1': tensor([[0.2743, 0.3101],
#         [0.2798, 0.3167]]), 'b1': tensor([[0.0358],
#         [0.0369]]), 'W2': tensor([[0.3861],
#         [0.4091]]), 'b2': tensor([[0.1595]])}
# X_sample tensor([[5.],
#         [6.]])
# y_sample 4.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.2743, 0.3101],
#         [0.2798, 0.3167]]), 'b1': tensor([[0.0358],
#         [0.0369]]), 'W2': tensor([[0.3861],
#         [0.4091]]), 'b2': tensor([[0.1595]])}
# iteration i and j 9 and 1 er parames {'W1': tensor([[0.2791, 0.3159],
#         [0.2849, 0.3229]]), 'b1': tensor([[0.0367],
#         [0.0379]]), 'W2': tensor([[0.3936],
#         [0.4176]]), 'b2': tensor([[0.1620]])}
# X_sample tensor([[7.],
#         [8.]])
# y_sample 5.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.2791, 0.3159],
#         [0.2849, 0.3229]]), 'b1': tensor([[0.0367],
#         [0.0379]]), 'W2': tensor([[0.3936],
#         [0.4176]]), 'b2': tensor([[0.1620]])}
# iteration i and j 9 and 2 er parames {'W1': tensor([[0.2856, 0.3232],
#         [0.2918, 0.3307]]), 'b1': tensor([[0.0377],
#         [0.0389]]), 'W2': tensor([[0.4033],
#         [0.4286]]), 'b2': tensor([[0.1642]])}
# Epoch - 10 Loss - 1.8559001684188843
# X_sample tensor([[2.],
#         [3.]])
# y_sample 3.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.2856, 0.3232],
#         [0.2918, 0.3307]]), 'b1': tensor([[0.0377],
#         [0.0389]]), 'W2': tensor([[0.4033],
#         [0.4286]]), 'b2': tensor([[0.1642]])}
# iteration i and j 10 and 0 er parames {'W1': tensor([[0.2881, 0.3270],
#         [0.2944, 0.3346]]), 'b1': tensor([[0.0389],
#         [0.0402]]), 'W2': tensor([[0.4078],
#         [0.4337]]), 'b2': tensor([[0.1673]])}
# X_sample tensor([[5.],
#         [6.]])
# y_sample 4.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.2881, 0.3270],
#         [0.2944, 0.3346]]), 'b1': tensor([[0.0389],
#         [0.0402]]), 'W2': tensor([[0.4078],
#         [0.4337]]), 'b2': tensor([[0.1673]])}
# iteration i and j 10 and 1 er parames {'W1': tensor([[0.2918, 0.3315],
#         [0.2984, 0.3394]]), 'b1': tensor([[0.0397],
#         [0.0410]]), 'W2': tensor([[0.4138],
#         [0.4404]]), 'b2': tensor([[0.1691]])}
# X_sample tensor([[7.],
#         [8.]])
# y_sample 5.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.2918, 0.3315],
#         [0.2984, 0.3394]]), 'b1': tensor([[0.0397],
#         [0.0410]]), 'W2': tensor([[0.4138],
#         [0.4404]]), 'b2': tensor([[0.1691]])}
# iteration i and j 10 and 2 er parames {'W1': tensor([[0.2962, 0.3365],
#         [0.3031, 0.3448]]), 'b1': tensor([[0.0403],
#         [0.0417]]), 'W2': tensor([[0.4204],
#         [0.4480]]), 'b2': tensor([[0.1706]])}
# Epoch - 11 Loss - 1.2307940522829692
# X_sample tensor([[2.],
#         [3.]])
# y_sample 3.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.2962, 0.3365],
#         [0.3031, 0.3448]]), 'b1': tensor([[0.0403],
#         [0.0417]]), 'W2': tensor([[0.4204],
#         [0.4480]]), 'b2': tensor([[0.1706]])}
# iteration i and j 11 and 0 er parames {'W1': tensor([[0.2986, 0.3401],
#         [0.3056, 0.3486]]), 'b1': tensor([[0.0415],
#         [0.0430]]), 'W2': tensor([[0.4247],
#         [0.4529]]), 'b2': tensor([[0.1734]])}
# X_sample tensor([[5.],
#         [6.]])
# y_sample 4.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.2986, 0.3401],
#         [0.3056, 0.3486]]), 'b1': tensor([[0.0415],
#         [0.0430]]), 'W2': tensor([[0.4247],
#         [0.4529]]), 'b2': tensor([[0.1734]])}
# iteration i and j 11 and 1 er parames {'W1': tensor([[0.3014, 0.3435],
#         [0.3086, 0.3522]]), 'b1': tensor([[0.0420],
#         [0.0436]]), 'W2': tensor([[0.4292],
#         [0.4579]]), 'b2': tensor([[0.1747]])}
# X_sample tensor([[7.],
#         [8.]])
# y_sample 5.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.3014, 0.3435],
#         [0.3086, 0.3522]]), 'b1': tensor([[0.0420],
#         [0.0436]]), 'W2': tensor([[0.4292],
#         [0.4579]]), 'b2': tensor([[0.1747]])}
# iteration i and j 11 and 2 er parames {'W1': tensor([[0.3040, 0.3464],
#         [0.3114, 0.3554]]), 'b1': tensor([[0.0424],
#         [0.0440]]), 'W2': tensor([[0.4332],
#         [0.4625]]), 'b2': tensor([[0.1756]])}
# Epoch - 12 Loss - 0.8578900148471197
# X_sample tensor([[2.],
#         [3.]])
# y_sample 3.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.3040, 0.3464],
#         [0.3114, 0.3554]]), 'b1': tensor([[0.0424],
#         [0.0440]]), 'W2': tensor([[0.4332],
#         [0.4625]]), 'b2': tensor([[0.1756]])}
# iteration i and j 12 and 0 er parames {'W1': tensor([[0.3063, 0.3499],
#         [0.3139, 0.3590]]), 'b1': tensor([[0.0436],
#         [0.0452]]), 'W2': tensor([[0.4373],
#         [0.4672]]), 'b2': tensor([[0.1782]])}
# X_sample tensor([[5.],
#         [6.]])
# y_sample 4.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.3063, 0.3499],
#         [0.3139, 0.3590]]), 'b1': tensor([[0.0436],
#         [0.0452]]), 'W2': tensor([[0.4373],
#         [0.4672]]), 'b2': tensor([[0.1782]])}
# iteration i and j 12 and 1 er parames {'W1': tensor([[0.3084, 0.3523],
#         [0.3160, 0.3617]]), 'b1': tensor([[0.0440],
#         [0.0456]]), 'W2': tensor([[0.4405],
#         [0.4708]]), 'b2': tensor([[0.1791]])}
# X_sample tensor([[7.],
#         [8.]])
# y_sample 5.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.3084, 0.3523],
#         [0.3160, 0.3617]]), 'b1': tensor([[0.0440],
#         [0.0456]]), 'W2': tensor([[0.4405],
#         [0.4708]]), 'b2': tensor([[0.1791]])}
# iteration i and j 12 and 2 er parames {'W1': tensor([[0.3096, 0.3537],
#         [0.3173, 0.3631]]), 'b1': tensor([[0.0441],
#         [0.0458]]), 'W2': tensor([[0.4423],
#         [0.4729]]), 'b2': tensor([[0.1795]])}
# Epoch - 13 Loss - 0.6512058340013027
# X_sample tensor([[2.],
#         [3.]])
# y_sample 3.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.3096, 0.3537],
#         [0.3173, 0.3631]]), 'b1': tensor([[0.0441],
#         [0.0458]]), 'W2': tensor([[0.4423],
#         [0.4729]]), 'b2': tensor([[0.1795]])}
# iteration i and j 13 and 0 er parames {'W1': tensor([[0.3118, 0.3570],
#         [0.3197, 0.3667]]), 'b1': tensor([[0.0452],
#         [0.0470]]), 'W2': tensor([[0.4463],
#         [0.4775]]), 'b2': tensor([[0.1820]])}
# X_sample tensor([[5.],
#         [6.]])
# y_sample 4.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.3118, 0.3570],
#         [0.3197, 0.3667]]), 'b1': tensor([[0.0452],
#         [0.0470]]), 'W2': tensor([[0.4463],
#         [0.4775]]), 'b2': tensor([[0.1820]])}
# iteration i and j 13 and 1 er parames {'W1': tensor([[0.3132, 0.3587],
#         [0.3212, 0.3685]]), 'b1': tensor([[0.0455],
#         [0.0473]]), 'W2': tensor([[0.4486],
#         [0.4801]]), 'b2': tensor([[0.1826]])}
# X_sample tensor([[7.],
#         [8.]])
# y_sample 5.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.3132, 0.3587],
#         [0.3212, 0.3685]]), 'b1': tensor([[0.0455],
#         [0.0473]]), 'W2': tensor([[0.4486],
#         [0.4801]]), 'b2': tensor([[0.1826]])}
# iteration i and j 13 and 2 er parames {'W1': tensor([[0.3133, 0.3588],
#         [0.3213, 0.3686]]), 'b1': tensor([[0.0455],
#         [0.0473]]), 'W2': tensor([[0.4487],
#         [0.4803]]), 'b2': tensor([[0.1826]])}
# Epoch - 14 Loss - 0.542620119638741
# X_sample tensor([[2.],
#         [3.]])
# y_sample 3.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.3133, 0.3588],
#         [0.3213, 0.3686]]), 'b1': tensor([[0.0455],
#         [0.0473]]), 'W2': tensor([[0.4487],
#         [0.4803]]), 'b2': tensor([[0.1826]])}
# iteration i and j 14 and 0 er parames {'W1': tensor([[0.3154, 0.3621],
#         [0.3236, 0.3721]]), 'b1': tensor([[0.0466],
#         [0.0485]]), 'W2': tensor([[0.4526],
#         [0.4847]]), 'b2': tensor([[0.1850]])}
# X_sample tensor([[5.],
#         [6.]])
# y_sample 4.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.3154, 0.3621],
#         [0.3236, 0.3721]]), 'b1': tensor([[0.0466],
#         [0.0485]]), 'W2': tensor([[0.4526],
#         [0.4847]]), 'b2': tensor([[0.1850]])}
# iteration i and j 14 and 1 er parames {'W1': tensor([[0.3164, 0.3632],
#         [0.3247, 0.3734]]), 'b1': tensor([[0.0468],
#         [0.0487]]), 'W2': tensor([[0.4542],
#         [0.4865]]), 'b2': tensor([[0.1854]])}
# X_sample tensor([[7.],
#         [8.]])
# y_sample 5.0
# Length of parameters  2
# Old parames {'W1': tensor([[0.3164, 0.3632],
#         [0.3247, 0.3734]]), 'b1': tensor([[0.0468],
#         [0.0487]]), 'W2': tensor([[0.4542],
#         [0.4865]]), 'b2': tensor([[0.1854]])}
# iteration i and j 14 and 2 er parames {'W1': tensor([[0.3158, 0.3625],
#         [0.3240, 0.3725]]), 'b1': tensor([[0.0467],
#         [0.0486]]), 'W2': tensor([[0.4531],
#         [0.4853]]), 'b2': tensor([[0.1852]])}
# Epoch - 15 Loss - 0.4874172316243251
